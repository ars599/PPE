# %%
'''
So the perturbations and global mean TOA fluxes for each of ~500 parameter perturbations are in this directory.
Parameter perturbations here: https://github.com/qump-project/qump-hadgem3/blob/master/data/GA7ParametersWave1and2and3andAtmosWave2b_020916.csv
Netcdf file is https://github.com/qump-project/qump-hadgem3/blob/master/data/u-ae077_rtnt_global.nc
You can read csv file with:

import pandas as pd
f = pathname_to_csv_file_above
ga7 = pd.read_csv(f, header=0, skiprows=list(range(1, 25)))
del ga7['ROW TYPE']
del ga7['ATTRIBUTE_NAME']

To link csv and netcdf file, the netcdf file has a  realization coordinate called 1100000, 110XXXX etc. 
   where XXXX is in the Parameter column of the csv file. You’ll need to average over the time coordinate
   to get 1 number per perturbation, the global 5-year mean TOA flux.
To test you understand this data, you might want to plot the parameters v TOA for different parameters.
   Two_d_fsd_factor should come out as important but there are many others.

Cheers, David

https://esd.copernicus.org/preprints/esd-2022-11/esd-2022-11-supplement.pdf

surface wind , 3000 runs data

TS coupld runs 
'''

import pandas as pd
import os
os.getcwd()

# %cd /g/data/p66/ars599/work_ppe
# Out:
# /g/data/p66/ars599/work_ppe

# %% [markdown]
# ## Main Table

# %%
idir = '/g/data/p66/ars599/work_ppe/'
f = idir+'GA7ParametersWave1and2and3andAtmosWave2b_020916.csv'
ga7 = pd.read_csv(f, header=0, skiprows=list(range(1, 25)))
del ga7['ROW TYPE']
del ga7['ATTRIBUTE_NAME']

ga7
# Out:
#       Realisation  Initialisation  Parameters  ent_fac_dp  ent_fac_md  \
# 0               1               1           1    0.691806    1.461925
# 1               1               1           2    2.710683    0.660156
# 2               1               1           3    2.027768    2.095871
# 3               1               1           4    2.702454    2.197831
# 4               1               1           5    1.156743    0.010131
# ...           ...             ...         ...         ...         ...
# 2909            1               1        2910    1.545337    1.571368
# 2910            1               1        2911    1.605891    1.386033
# 2911            1               1        2912    1.537304    1.320986
# 2912            1               1        2913    1.339883    1.075359
# 2913            1               1        2914    0.466446    1.642883
#
#       amdet_fac     r_det  cca_md_knob  cca_dp_knob  cca_sh_knob  ...  \
# ...

# %% [markdown]
# ## ukcp18_strand2_ppe20

# %%
idir = '/g/data/p66/ars599/work_ppe/'
f = idir+'ukcp18_strand2_ppe20.csv'
ga7 = pd.read_csv(f, header=0, skiprows=list(range(1, 47)))
del ga7['ROW TYPE']
del ga7['ATTRIBUTE_NAME']

del ga7['Realisation']
del ga7['Initialisation']

ga7
# Out:
#     Parameters  ent_fac_dp  ent_fac_md  amdet_fac     r_det  cca_md_knob  \
# 0            0    1.130000    0.900000   3.000000  0.800000     0.100000
# 1           90    0.781927    1.301042   9.763362  0.753516     0.297660
# 2          605    1.118184    0.669165   6.713313  0.587380     0.247410
# 3          834    0.401628    1.709316   3.157218  0.626535     0.218360
# 4         1113    1.622962    1.344284   5.428193  0.859342     0.162016
# 5         1554    0.792976    1.381026   1.309205  0.568634     0.197674
# 6         1649    1.144268    0.391566   7.198681  0.681817     0.181899
# 7         1843    0.694337    0.734053   4.992597  0.819301     0.287509
# 8         1935    0.510300    1.210891  12.743134  0.924648     0.114586
# 9         2089    0.848965    1.319414   9.134000  0.920337     0.049339
# 10        2123    0.664382    0.633180   6.950254  0.846619     0.168762
# 11        2242    0.636621    0.621855   9.110474  0.577480     0.297069
# ...

# %% [markdown]
# ## Parameter analysis

# %%
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 6)  # Default plot size
row_12 = ga7.iloc[11]
row_14 = ga7.iloc[13]
row_19 = ga7.iloc[18]

row_17 = ga7.iloc[16]
row_13 = ga7.iloc[12]
row_15 = ga7.iloc[14]
row_16 = ga7.iloc[15]
row_18 = ga7.iloc[17]

# Apply division for elements higher than 1000
plt.subplot(211)
(row_12.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='12', lw=4, linestyle='-', color='lightblue', marker='o')
(row_14.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='14', lw=4, linestyle='-', color='blue', marker='o')
(row_19.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='19', lw=4, linestyle='-', color='darkblue', marker='o')

(row_17.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='17', linestyle='-', marker='x')
(row_13.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='13', linestyle='-', marker='x')
(row_15.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='15', linestyle='-', marker='x')
(row_16.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='16', linestyle='-', marker='x')
(row_18.apply(lambda x: x / 1000000 if x > 10 else x)).plot(label='18', linestyle='-', marker='x')
plt.legend(); plt.grid()
plt.xticks(ticks=range(len(row_12)), labels=row_12.index, rotation=90);  # Show all x-axis labels

from numpy import nan
plt.subplot(212)
(row_12.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='12', lw=4, linestyle='-', color='lightblue', marker='o')
(row_14.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='14', lw=4, linestyle='-', color='blue', marker='o')
(row_19.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='19', lw=4, linestyle='-', color='darkblue', marker='o')

(row_17.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='17', linestyle='-', marker='x')
(row_13.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='13', linestyle='-', marker='x')
(row_15.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='15', linestyle='-', marker='x')
(row_16.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='16', linestyle='-', marker='x')
(row_18.apply(lambda x: nan if abs(x) > 2 else x)).plot(label='18', linestyle='-', marker='x')
plt.legend(); plt.grid()
plt.xticks(ticks=range(len(row_12)), labels=row_12.index, rotation=90);  # Show all x-axis labels

plt.savefig('ppe_parameters_v1.png', dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (16, 10)  # Default plot size

# Assuming row_12 contains 53 elements
row_12 = ga7.iloc[11][:53].apply(lambda x: nan if abs(x) > 2 else x)
row_13 = ga7.iloc[12][:53].apply(lambda x: nan if abs(x) > 2 else x)
row_14 = ga7.iloc[13][:53].apply(lambda x: nan if abs(x) > 2 else x)
row_15 = ga7.iloc[14][:53].apply(lambda x: nan if abs(x) > 2 else x)
row_16 = ga7.iloc[15][:53].apply(lambda x: nan if abs(x) > 2 else x)
row_17 = ga7.iloc[16][:53].apply(lambda x: nan if abs(x) > 2 else x)
row_18 = ga7.iloc[17][:53].apply(lambda x: nan if abs(x) > 2 else x)

# Calculate the angles for each element in row_12
theta = np.linspace(0, 2 * np.pi, len(row_12), endpoint=False)

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

ax.scatter(theta, row_12.values, marker='o', s=20)
ax.scatter(theta, row_13.values, marker='o', s=20)
ax.scatter(theta, row_14.values, marker='o', s=20)
ax.scatter(theta, row_15.values, marker='o', s=20)
ax.scatter(theta, row_16.values, marker='o', s=20)
ax.scatter(theta, row_17.values, marker='o', s=20)
ax.scatter(theta, row_18.values, marker='o', s=20)

ax.set_xticks(theta)  # Set ticks at calculated angles
ax.set_xticklabels([label[:4] for label in row_12.index], rotation=60, ha='center');  # Set labels based on row_12 index with a 60-degree rotation and adjust alignment, showing only the first 5 characters
plt.savefig('ppe_parameters_circle_v1.png', dpi=300)

# %% [markdown]
# ## ENSO ukcp18 15 coupled runs

# %%
idir = '/g/data/p66/ars599/work_ppe/'
f = idir+'ukcp18_strand2_ppe15.csv'
ga7 = pd.read_csv(f, header=0, skiprows=list(range(1, 47)))
del ga7['ROW TYPE']
del ga7['ATTRIBUTE_NAME']
del ga7['Realisation']
del ga7['Initialisation']
del ga7['Parameters']

# ukcp18_15 = ['r001i1p00000', 'r001i1p00605', 'r001i1p00834', 'r001i1p01113', 'r001i1p01554',
#              'r001i1p01649', 'r001i1p01843', 'r001i1p01935', 'r001i1p02123', 'r001i1p02242',
#              'r001i1p02305', 'r001i1p02335', 'r001i1p02491', 'r001i1p02832', 'r001i1p02868']


ga7
# Out:
#     ent_fac_dp  ent_fac_md  amdet_fac     r_det  cca_md_knob  cca_dp_knob  \
# 0     1.130000    0.900000   3.000000  0.800000     0.100000     0.100000
# 1     1.118184    0.669165   6.713313  0.587380     0.247410     0.247410
# 2     0.401628    1.709316   3.157218  0.626535     0.218360     0.218360
# 3     1.622962    1.344284   5.428193  0.859342     0.162016     0.162016
# 4     0.792976    1.381026   1.309205  0.568634     0.197674     0.197674
# 5     1.144268    0.391566   7.198681  0.681817     0.181899     0.181899
# 6     0.694337    0.734053   4.992597  0.819301     0.287509     0.287509
# 7     0.510300    1.210891  12.743134  0.924648     0.114586     0.114586
# 8     0.664382    0.633180   6.950254  0.846619     0.168762     0.168762
# 9     0.636621    0.621855   9.110474  0.577480     0.297069     0.297069
# 10    1.026864    1.801745   2.412738  0.673921     0.177172     0.177172
# 11    1.099859    1.817280   2.013084  0.642843     0.222404     0.222404
# ...

# %% [markdown]
# ### replace value in the namelist file

# %%
'''
ksh / bash (need to double check)
'''
ed input.nml <<eof
g/#NMONTH/s/#NMONTH/${nmonth}/
g/#NDAY/s/#NDAY/${nday}/
g/#SYEAR/s/#SYEAR/${iniyear}/
g/#SMON/s/#SMON/${inimonth}/
g/#SDAY/s/#SDAY/${iniday}/
g/#CAL_TYPE/s/#CAL_TYPE/${cal_type}/
g/#DT_CPL/s/#DT_CPL/${dt_cpl_io}/
g/#DT_OCE/s/#DT_OCE/${dt_ocn}/
g/#LAYOUT/s/#LAYOUT/${layout}/
g/#VLIMIT/s/#VLIMIT/${truncate_velocity}/
g/#VWARN/s/#VWARN/${truncate_verbose}/
~~~~
g/#USE_waterflux/s/#USE_waterflux/${use_waterflux}/
g/background_diffusivity=5.0e-6/s/background_diffusivity=5.0e-6/background_diffusivity=1.0e-5/
w
q
eof

# %%
'''
python
for Quino
'''
# csv contains all the namelist name and value
idir = '/g/data/p66/ars599/work_ppe/'
f = idir+'ukcp18_strand2_ppe15.csv'
ga7 = pd.read_csv(f, header=0, skiprows=list(range(1, 47)))
del ga7['ROW TYPE']
del ga7['ATTRIBUTE_NAME']
del ga7['Realisation']
del ga7['Initialisation']
del ga7['Parameters']

# name list file is rose-appxxxxxx.conf
# loop the experiment #
exp_num = 1
for jj in range(exp_num):
    sel_row = ga7.iloc[jj]  # Note that row numbers are zero-based, so the 5th row is at index 4
    outName = 'rose-app-exp{:03d}.conf'.format(ga7.index[jj])
    sel_num = sel_row.shape[0]
    print(outName + ' and selected row number' + str(sel_num))

    # loop the parameters
    for ii in range(sel_num):
        name_to_find = sel_row.index[ii]  # Index name
        new_value = sel_row.iloc[ii]  # Corresponding value
        #print(f'{name_to_find} and the value is {new_value}')

        # Iterate through the lines
        for i, line in enumerate(lines):
            # Split each line into name and value using '=' as the delimiter
            parts = line.strip().split('=')

            # Check if the name matches the one you want to update
            if parts[0].strip() == name_to_find:
                # Check if the name matches any of the specified names
                if name_to_find in ['dz0v_dh_io', 'f0_io', 'nl0_io', 'rootd_ft_io', 'tupp_io']:
                    parts[1] = f'13*{new_value:.6f}\n'
                else:
                    parts[1] = f'{new_value:.6f}\n'
                # Update the value with the new value
                # parts[1] = f'{new_value:.6f}\n'  # Ensure the format is correct with a space before the new value
                # Use {:.6f} to format the new_value as a float with 6 decimal places

                # Join the parts back into a modified line
                modified_line = '='.join(parts)

                # Replace the line in the list
                lines[i] = modified_line
    # Write the modified lines back to the text file
    with open(outName, 'w') as file:
        file.writelines(lines)

# %% [markdown]
# ## UM Namelist

# %%
'''
000 is the reference run or the CMIP6 run use
# 001-0014 are the runs from GJ 15 ENSO could analysis
rose-app-exp000.conf:ent_fac_dp=1.130000
rose-app-exp001.conf:ent_fac_dp=1.118184
rose-app-exp002.conf:ent_fac_dp=0.401628
rose-app-exp003.conf:ent_fac_dp=1.622962
rose-app-exp004.conf:ent_fac_dp=0.792976
rose-app-exp005.conf:ent_fac_dp=1.144268
rose-app-exp006.conf:ent_fac_dp=0.694337
rose-app-exp007.conf:ent_fac_dp=0.510300
rose-app-exp008.conf:ent_fac_dp=0.664382
rose-app-exp009.conf:ent_fac_dp=0.636621
rose-app-exp010.conf:ent_fac_dp=1.026864
rose-app-exp011.conf:ent_fac_dp=1.099859
rose-app-exp012.conf:ent_fac_dp=0.754394
rose-app-exp013.conf:ent_fac_dp=1.045090
rose-app-exp014.conf:ent_fac_dp=1.169802

# 015-019 are the one from PPE 20 experiments the last five runs
rose-app-exp015.conf:ent_fac_dp=1.221180
rose-app-exp016.conf:ent_fac_dp=1.045090
rose-app-exp017.conf:ent_fac_dp=1.169802
rose-app-exp018.conf:ent_fac_dp=1.226887
rose-app-exp019.conf:ent_fac_dp=0.466446

# name list from one of the CM2 runs
rose-app.conf:ent_fac_dp=1.13
'''

# %% [markdown]
# ## Next step:
# * 1. CMORise the data
# * 2. Run the Yann's ENSO Metrix

# %%
'''
Dave's cj888G12.json to cj888G19.json

/g/data/p66/ars599/CMIP6/APP_output/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/piControl/
r3i1p12f1/
r3i1p13f1/
r3i1p14f1/
r3i1p15f1/
r3i1p16f1/
r3i1p17f1/
r3i1p18f1/
r3i1p19f1/

To do list:
1. Need to add fx and taux tauy for metrix
2. This is the base run, suggest turning on daily output (but from piControl need some work)

'''
